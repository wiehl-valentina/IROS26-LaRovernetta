# %% [markdown]
# Se la da contra una reja a metros del primer checkpoint

# %% [markdown]
# '''
# ==============================================================
#   MODO REAL: el rover se va a mover. Ctrl-C frena.
#   Tene el robot a la vista y espacio libre alrededor.
# ==============================================================
#   3 ...
#   2 ...
#   1 ...
# [bridge] Objetivo: checkpoint #1 (-21.98324013, 27.83091354)
# [bridge] ✓ checkpoint #1 conseguido: {'message': 'Checkpoint reached successfully', 'next_checkpoint_sequence': 2, 'mission_completed': False}
# [percep] frame 1024x576 != calibracion 1920x1080: reescalo K (sx=0.533, sy=0.533)
# [0000] rumbo=328 (orientation)  meta: cp#1 a 3 m, rel -179 grados  celdas BEV=2994  mapa: 2949 celdas  pose=(+0.00,+0.00,+0gr)
# [bridge] banco de 222 caminos candidatos precalculado en 0.1 s (se reusa durante toda la corrida)
#   [ENVIADO] linear=+0.64 angular=+0.45  siguiendo camino (-64 grados)
# [0001] rumbo=324 (orientation)  meta: cp#2 a 40 m, rel -12 grados  celdas BEV=2994  mapa: 2949 celdas  pose=(+0.00,+0.00,+0gr)
#   [ENVIADO] linear=+0.92 angular=-0.11  siguiendo camino (+15 grados)
# [0002] rumbo=348 (orientation)  meta: cp#2 a 40 m, rel -36 grados  celdas BEV=2994  mapa: 2949 celdas  pose=(+0.01,+0.00,+0gr)
#   [ENVIADO] linear=+0.62 angular=+0.45  siguiendo camino (-68 grados)
# [0003] rumbo=15 (orientation)  meta: cp#2 a 40 m, rel -63 grados  celdas BEV=2994  mapa: 3978 celdas  pose=(+0.02,-0.00,-0gr)
#   [ENVIADO] linear=+0.62 angular=+0.45  siguiendo camino (-68 grados)
# [0004] rumbo=357 (orientation)  meta: cp#2 a 40 m, rel -45 grados  celdas BEV=2994  mapa: 4307 celdas  pose=(+0.04,-0.00,-1gr)
#   [ENVIADO] linear=+0.62 angular=+0.45  siguiendo camino (-69 grados)
# [0005] rumbo=359 (orientation)  meta: cp#2 a 40 m, rel -47 grados  celdas BEV=2994  mapa: 4474 celdas  pose=(+0.05,-0.00,-1gr)
#   [ENVIADO] linear=+0.62 angular=+0.45  siguiendo camino (-68 grados)
# [0006] rumbo=18 (orientation)  meta: cp#2 a 40 m, rel -65 grados  celdas BEV=2994  mapa: 4587 celdas  pose=(+0.07,-0.00,-1gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  OBSTACULO al frente
# [0007] rumbo=19 (orientation)  meta: cp#2 a 41 m, rel -66 grados  celdas BEV=2994  mapa: 4684 celdas  pose=(+0.09,-0.00,-0gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  OBSTACULO al frente
# [0008] rumbo=11 (orientation)  meta: cp#2 a 41 m, rel -57 grados  celdas BEV=2994  mapa: 4684 celdas  pose=(+0.09,-0.00,-0gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  OBSTACULO al frente
# [0009] rumbo=11 (orientation)  meta: cp#2 a 41 m, rel -57 grados  celdas BEV=2994  mapa: 4684 celdas  pose=(+0.09,-0.00,-0gr)
# [bridge] REGIMEN CERCANO: 4 frames bloqueado seguidos, clearance=0.35 m
# [bridge]   mapa detras del robot: libre=0% cobertura=0%
# [bridge]   detras no parece seguro (o sin datos todavia), salteo el retroceso
# [bridge]   rumbo +0 grados: libre=15% cobertura=72%
# [bridge]   rumbo +90 grados: libre=11% cobertura=17%
# [bridge]   rumbo -90 grados: libre=31% cobertura=19%
# [bridge]   rumbo +180 grados: libre=0% cobertura=0%
# [bridge]   elijo rumbo +0 grados por mapa (libre=15%)
# [0010] rumbo=11 (orientation)  meta: cp#2 a 41 m, rel -57 grados  celdas BEV=2994  mapa: 4684 celdas  pose=(+0.09,-0.00,-0gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  OBSTACULO al frente
# [0011] rumbo=11 (orientation)  meta: cp#2 a 41 m, rel -57 grados  celdas BEV=2994  mapa: 4493 celdas  pose=(+0.09,-0.00,-0gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  OBSTACULO al frente
# [0012] rumbo=11 (orientation)  meta: cp#2 a 41 m, rel -57 grados  celdas BEV=2994  mapa: 4493 celdas  pose=(+0.09,-0.00,-0gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  OBSTACULO al frente
# [0013] rumbo=11 (orientation)  meta: cp#2 a 41 m, rel -57 grados  celdas BEV=2994  mapa: 4493 celdas  pose=(+0.09,-0.00,-0gr)
# [bridge] REGIMEN CERCANO: 4 frames bloqueado seguidos, clearance=0.35 m
# [bridge]   mapa detras del robot: libre=0% cobertura=0%
# [bridge]   detras no parece seguro (o sin datos todavia), salteo el retroceso
# [bridge]   rumbo +0 grados: libre=18% cobertura=70%
# [bridge]   rumbo +90 grados: libre=14% cobertura=17%
# [bridge]   rumbo -90 grados: libre=28% cobertura=18%
# [bridge]   rumbo +180 grados: libre=0% cobertura=0%
# [bridge]   elijo rumbo +0 grados por mapa (libre=18%)
# [0014] rumbo=11 (orientation)  meta: cp#2 a 41 m, rel -57 grados  celdas BEV=2994  mapa: 4431 celdas  pose=(+0.09,-0.00,-0gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  OBSTACULO al frente
# [0015] rumbo=11 (orientation)  meta: cp#2 a 42 m, rel -57 grados  celdas BEV=2994  mapa: 4359 celdas  pose=(+0.09,-0.00,-0gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  OBSTACULO al frente
# [0016] rumbo=11 (orientation)  meta: cp#2 a 42 m, rel -57 grados  celdas BEV=2994  mapa: 4166 celdas  pose=(+0.09,-0.00,-0gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  OBSTACULO al frente
# [0017] rumbo=11 (orientation)  meta: cp#2 a 42 m, rel -57 grados  celdas BEV=2994  mapa: 3971 celdas  pose=(+0.09,-0.00,-0gr)
# [bridge] REGIMEN CERCANO: 4 frames bloqueado seguidos, clearance=0.35 m
# [bridge]   mapa detras del robot: libre=0% cobertura=0%
# [bridge]   detras no parece seguro (o sin datos todavia), salteo el retroceso
# [bridge]   rumbo +0 grados: libre=27% cobertura=64%
# [bridge]   rumbo +90 grados: libre=9% cobertura=16%
# [bridge]   rumbo -90 grados: libre=27% cobertura=18%
# [bridge]   rumbo +180 grados: libre=0% cobertura=0%
# [bridge]   elijo rumbo +0 grados por mapa (libre=27%)
# [0018] rumbo=11 (orientation)  meta: cp#2 a 42 m, rel -57 grados  celdas BEV=2994  mapa: 3581 celdas  pose=(+0.09,-0.00,-0gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  OBSTACULO al frente
# [0019] rumbo=11 (orientation)  meta: cp#2 a 42 m, rel -57 grados  celdas BEV=2994  mapa: 2994 celdas  pose=(+0.09,-0.00,-0gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  OBSTACULO al frente
# [0020] rumbo=11 (orientation)  meta: cp#2 a 42 m, rel -57 grados  celdas BEV=2994  mapa: 2994 celdas  pose=(+0.09,-0.00,-0gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  OBSTACULO al frente
# [0021] rumbo=11 (orientation)  meta: cp#2 a 42 m, rel -57 grados  celdas BEV=2994  mapa: 2994 celdas  pose=(+0.09,-0.00,-0gr)
# [bridge] REGIMEN CERCANO: 4 frames bloqueado seguidos, clearance=0.35 m
# [bridge]   mapa detras del robot: libre=0% cobertura=0%
# [bridge]   detras no parece seguro (o sin datos todavia), salteo el retroceso
# [bridge]   rumbo +0 grados: libre=6% cobertura=50%
# [bridge]   rumbo +90 grados: libre=1% cobertura=14%
# [bridge]   rumbo -90 grados: libre=18% cobertura=16%
# [bridge]   rumbo +180 grados: libre=0% cobertura=0%
# [bridge]   elijo rumbo +0 grados por mapa (libre=6%)
# [0022] rumbo=11 (orientation)  meta: cp#2 a 42 m, rel -57 grados  celdas BEV=2994  mapa: 2994 celdas  pose=(+0.09,-0.00,-0gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  OBSTACULO al frente
# [0023] rumbo=11 (orientation)  meta: cp#2 a 42 m, rel -58 grados  celdas BEV=2994  mapa: 2994 celdas  pose=(+0.09,-0.00,-0gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  OBSTACULO al frente
# [0024] rumbo=11 (orientation)  meta: cp#2 a 41 m, rel -58 grados  celdas BEV=2994  mapa: 2994 celdas  pose=(+0.09,-0.00,-0gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  OBSTACULO al frente
# [0025] rumbo=11 (orientation)  meta: cp#2 a 41 m, rel -58 grados  celdas BEV=2994  mapa: 2994 celdas  pose=(+0.09,-0.00,-0gr)
# [bridge] REGIMEN CERCANO: 4 frames bloqueado seguidos, clearance=0.35 m
# [bridge]   mapa detras del robot: libre=0% cobertura=0%
# [bridge]   detras no parece seguro (o sin datos todavia), salteo el retroceso
# [bridge]   rumbo +0 grados: libre=5% cobertura=50%
# [bridge]   rumbo +90 grados: libre=1% cobertura=14%
# [bridge]   rumbo -90 grados: libre=17% cobertura=16%
# [bridge]   rumbo +180 grados: libre=0% cobertura=0%
# [bridge]   elijo rumbo +0 grados por mapa (libre=5%)
# [0026] rumbo=11 (orientation)  meta: cp#2 a 41 m, rel -58 grados  celdas BEV=2994  mapa: 2994 celdas  pose=(+0.09,-0.00,-0gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  OBSTACULO al frente
# [0027] rumbo=11 (orientation)  meta: cp#2 a 41 m, rel -58 grados  celdas BEV=2994  mapa: 2994 celdas  pose=(+0.09,-0.00,-0gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  OBSTACULO al frente
# [0028] rumbo=26 (orientation)  meta: cp#2 a 40 m, rel -73 grados  celdas BEV=2994  mapa: 3777 celdas  pose=(+0.09,-0.00,-3gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  OBSTACULO al frente
# [0029] rumbo=16 (orientation)  meta: cp#2 a 40 m, rel -63 grados  celdas BEV=2994  mapa: 3777 celdas  pose=(+0.09,-0.00,-3gr)
#   [ENVIADO] linear=+0.73 angular=-0.37  siguiendo camino (+48 grados)
# [0030] rumbo=352 (orientation)  meta: cp#2 a 40 m, rel -39 grados  celdas BEV=2994  mapa: 3777 celdas  pose=(+0.09,-0.00,-3gr)
#   [ENVIADO] linear=+0.73 angular=-0.37  siguiendo camino (+48 grados)
# [0031] rumbo=1 (orientation)  meta: cp#2 a 40 m, rel -48 grados  celdas BEV=2994  mapa: 3972 celdas  pose=(+0.10,-0.00,-3gr)
#   [ENVIADO] linear=+0.97 angular=-0.04  siguiendo camino (+5 grados)
# [0032] rumbo=356 (orientation)  meta: cp#2 a 40 m, rel -43 grados  celdas BEV=2994  mapa: 4416 celdas  pose=(+0.13,-0.00,-7gr)
#   [ENVIADO] linear=+0.99 angular=-0.01  siguiendo camino (+1 grados)
# [0033] rumbo=293 (orientation)  meta: cp#2 a 40 m, rel +21 grados  celdas BEV=2994  mapa: 4652 celdas  pose=(+0.15,-0.01,-7gr)
#   [ENVIADO] linear=+0.91 angular=-0.13  siguiendo camino (+17 grados)
# [0034] rumbo=295 (orientation)  meta: cp#2 a 41 m, rel +20 grados  celdas BEV=2994  mapa: 4929 celdas  pose=(+0.19,-0.01,-7gr)
#   [ENVIADO] linear=+0.92 angular=-0.12  siguiendo camino (+15 grados)
# [0035] rumbo=285 (orientation)  meta: cp#2 a 41 m, rel +31 grados  celdas BEV=2994  mapa: 5028 celdas  pose=(+0.21,-0.01,-7gr)
#   [ENVIADO] linear=+0.91 angular=-0.13  siguiendo camino (+16 grados)
# [0036] rumbo=287 (orientation)  meta: cp#2 a 42 m, rel +30 grados  celdas BEV=2994  mapa: 5164 celdas  pose=(+0.24,-0.02,-7gr)
#   [ENVIADO] linear=+0.90 angular=-0.14  siguiendo camino (+17 grados)
# [0037] rumbo=305 (orientation)  meta: cp#2 a 42 m, rel +12 grados  celdas BEV=2994  mapa: 5288 celdas  pose=(+0.29,-0.02,-8gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0038] rumbo=292 (orientation)  meta: cp#2 a 42 m, rel +26 grados  celdas BEV=2994  mapa: 5398 celdas  pose=(+0.31,-0.03,-8gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0039] rumbo=290 (orientation)  meta: cp#2 a 42 m, rel +28 grados  celdas BEV=2994  mapa: 5366 celdas  pose=(+0.31,-0.03,-8gr)
# [bridge] RECUPERACION: buscando rumbo transitable (3 planes vacios seguidos)
# [bridge]   rumbo +0 grados: libre=90% cobertura=80%
# [bridge]   rumbo +90 grados: libre=88% cobertura=27%
# [bridge]   rumbo -90 grados: libre=100% cobertura=21%
# [bridge]   rumbo +180 grados: libre=100% cobertura=1%
# [bridge]   elijo rumbo +0 grados por mapa (libre=90%)
# [0040] rumbo=290 (orientation)  meta: cp#2 a 42 m, rel +28 grados  celdas BEV=2994  mapa: 5266 celdas  pose=(+0.33,-0.03,-8gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0041] rumbo=291 (orientation)  meta: cp#2 a 42 m, rel +27 grados  celdas BEV=2994  mapa: 5262 celdas  pose=(+0.33,-0.03,-8gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0042] rumbo=291 (orientation)  meta: cp#2 a 42 m, rel +27 grados  celdas BEV=2994  mapa: 5236 celdas  pose=(+0.33,-0.03,-8gr)
# [bridge] RECUPERACION: buscando rumbo transitable (3 planes vacios seguidos)
# [bridge]   rumbo +0 grados: libre=93% cobertura=79%
# [bridge]   rumbo +90 grados: libre=100% cobertura=25%
# [bridge]   rumbo -90 grados: libre=100% cobertura=21%
# [bridge]   rumbo +180 grados: libre=100% cobertura=1%
# [bridge]   elijo rumbo +90 grados por mapa (libre=100%)
#   [ENVIADO] linear=+0.00 angular=-0.45  girando hacia +90 grados (regimen cercano)
# [bridge]   frente libre por mapa tras girar +45 grados, corto
#   [ENVIADO] linear=+0.00 angular=+0.00  fin del giro
# [0043] rumbo=291 (orientation)  meta: cp#2 a 42 m, rel +27 grados  celdas BEV=2994  mapa: 4929 celdas  pose=(+0.33,-0.03,-8gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0044] rumbo=290 (orientation)  meta: cp#2 a 43 m, rel +28 grados  celdas BEV=2994  mapa: 4887 celdas  pose=(+0.33,-0.03,-8gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0045] rumbo=290 (orientation)  meta: cp#2 a 43 m, rel +28 grados  celdas BEV=2994  mapa: 4741 celdas  pose=(+0.33,-0.03,-8gr)
# [bridge] RECUPERACION: buscando rumbo transitable (3 planes vacios seguidos)
# [bridge]   rumbo +0 grados: libre=95% cobertura=74%
# [bridge]   rumbo +90 grados: libre=100% cobertura=21%
# [bridge]   rumbo -90 grados: libre=100% cobertura=20%
# [bridge]   rumbo +180 grados: libre=0% cobertura=0%
# [bridge]   elijo rumbo +0 grados por mapa (libre=95%)
# [0046] rumbo=290 (orientation)  meta: cp#2 a 43 m, rel +28 grados  celdas BEV=2994  mapa: 4624 celdas  pose=(+0.33,-0.03,-8gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0047] rumbo=290 (orientation)  meta: cp#2 a 43 m, rel +28 grados  celdas BEV=2994  mapa: 4509 celdas  pose=(+0.33,-0.03,-8gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0048] rumbo=290 (orientation)  meta: cp#2 a 43 m, rel +28 grados  celdas BEV=2994  mapa: 4324 celdas  pose=(+0.33,-0.03,-8gr)
#   [ENVIADO] linear=+0.80 angular=-0.28  siguiendo camino (+36 grados)
# [0049] rumbo=290 (orientation)  meta: cp#2 a 43 m, rel +28 grados  celdas BEV=2994  mapa: 4045 celdas  pose=(+0.33,-0.03,-8gr)
#   [ENVIADO] linear=+0.80 angular=-0.28  siguiendo camino (+36 grados)
# [0050] rumbo=304 (orientation)  meta: cp#2 a 43 m, rel +14 grados  celdas BEV=2994  mapa: 3942 celdas  pose=(+0.34,-0.03,-9gr)
#   [ENVIADO] linear=+0.85 angular=-0.22  siguiendo camino (+28 grados)
# [0051] rumbo=287 (orientation)  meta: cp#2 a 43 m, rel +32 grados  celdas BEV=2994  mapa: 4240 celdas  pose=(+0.35,-0.03,-9gr)
#   [ENVIADO] linear=+0.84 angular=-0.22  siguiendo camino (+28 grados)
# [0052] rumbo=294 (orientation)  meta: cp#2 a 43 m, rel +25 grados  celdas BEV=2994  mapa: 4390 celdas  pose=(+0.38,-0.04,-8gr)
#   [ENVIADO] linear=+0.78 angular=-0.31  siguiendo camino (+39 grados)
# [0053] rumbo=299 (orientation)  meta: cp#2 a 43 m, rel +20 grados  celdas BEV=2994  mapa: 4562 celdas  pose=(+0.43,-0.04,-8gr)
#   [ENVIADO] linear=+0.77 angular=-0.32  siguiendo camino (+41 grados)
# [0054] rumbo=300 (orientation)  meta: cp#2 a 43 m, rel +20 grados  celdas BEV=2994  mapa: 4676 celdas  pose=(+0.44,-0.05,-8gr)
#   [ENVIADO] linear=+0.79 angular=-0.29  siguiendo camino (+37 grados)
# [0055] rumbo=315 (orientation)  meta: cp#2 a 43 m, rel +5 grados  celdas BEV=2994  mapa: 4887 celdas  pose=(+0.48,-0.05,-8gr)
#   [ENVIADO] linear=+0.84 angular=-0.22  siguiendo camino (+28 grados)
# [0056] rumbo=318 (orientation)  meta: cp#2 a 42 m, rel +3 grados  celdas BEV=2994  mapa: 4963 celdas  pose=(+0.50,-0.05,-8gr)
#   [ENVIADO] linear=+0.84 angular=-0.22  siguiendo camino (+29 grados)
# [0057] rumbo=319 (orientation)  meta: cp#2 a 42 m, rel +3 grados  celdas BEV=2994  mapa: 5085 celdas  pose=(+0.52,-0.06,-8gr)
#   [ENVIADO] linear=+0.94 angular=-0.08  siguiendo camino (+10 grados)
# [0058] rumbo=325 (orientation)  meta: cp#2 a 41 m, rel -3 grados  celdas BEV=2994  mapa: 5199 celdas  pose=(+0.55,-0.06,-8gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0059] rumbo=331 (orientation)  meta: cp#2 a 41 m, rel -9 grados  celdas BEV=2994  mapa: 5283 celdas  pose=(+0.57,-0.06,-8gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0060] rumbo=331 (orientation)  meta: cp#2 a 40 m, rel -9 grados  celdas BEV=2994  mapa: 5258 celdas  pose=(+0.57,-0.06,-8gr)
# [bridge] RECUPERACION: buscando rumbo transitable (3 planes vacios seguidos)
# [bridge]   rumbo +0 grados: libre=84% cobertura=80%
# [bridge]   rumbo +90 grados: libre=95% cobertura=21%
# [bridge]   rumbo -90 grados: libre=100% cobertura=24%
# [bridge]   rumbo +180 grados: libre=100% cobertura=1%
# [bridge]   elijo rumbo +0 grados por mapa (libre=84%)
# [0061] rumbo=331 (orientation)  meta: cp#2 a 41 m, rel -9 grados  celdas BEV=2994  mapa: 5247 celdas  pose=(+0.57,-0.06,-8gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0062] rumbo=331 (orientation)  meta: cp#2 a 41 m, rel -9 grados  celdas BEV=2994  mapa: 5193 celdas  pose=(+0.57,-0.06,-8gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0063] rumbo=331 (orientation)  meta: cp#2 a 41 m, rel -9 grados  celdas BEV=2994  mapa: 5112 celdas  pose=(+0.57,-0.06,-8gr)
# [bridge] RECUPERACION: buscando rumbo transitable (3 planes vacios seguidos)
# [bridge]   rumbo +0 grados: libre=84% cobertura=79%
# [bridge]   rumbo +90 grados: libre=93% cobertura=20%
# [bridge]   rumbo -90 grados: libre=100% cobertura=23%
# [bridge]   rumbo +180 grados: libre=100% cobertura=0%
# [bridge]   elijo rumbo +0 grados por mapa (libre=84%)
# [0064] rumbo=331 (orientation)  meta: cp#2 a 41 m, rel -9 grados  celdas BEV=2994  mapa: 4976 celdas  pose=(+0.57,-0.06,-8gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0065] rumbo=332 (orientation)  meta: cp#2 a 41 m, rel -10 grados  celdas BEV=2994  mapa: 4730 celdas  pose=(+0.57,-0.06,-8gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0066] rumbo=332 (orientation)  meta: cp#2 a 41 m, rel -9 grados  celdas BEV=2994  mapa: 4583 celdas  pose=(+0.57,-0.06,-8gr)
# [bridge] RECUPERACION: buscando rumbo transitable (3 planes vacios seguidos)
# [bridge]   rumbo +0 grados: libre=83% cobertura=72%
# [bridge]   rumbo +90 grados: libre=91% cobertura=18%
# [bridge]   rumbo -90 grados: libre=100% cobertura=20%
# [bridge]   rumbo +180 grados: libre=0% cobertura=0%
# [bridge]   elijo rumbo +0 grados por mapa (libre=83%)
# [0067] rumbo=332 (orientation)  meta: cp#2 a 41 m, rel -9 grados  celdas BEV=2994  mapa: 4428 celdas  pose=(+0.57,-0.06,-8gr)
#   [ENVIADO] linear=+0.93 angular=+0.11  siguiendo camino (-13 grados)
# [bridge] error en la iteracion (1/5): 500 Server Error:  for url: http://localhost:8000/control
#   [ENVIADO] linear=+0.00 angular=+0.00  freno por error
# [0068] rumbo=332 (orientation)  meta: cp#2 a 41 m, rel -9 grados  celdas BEV=2994  mapa: 4177 celdas  pose=(+0.57,-0.06,-8gr)
#   [ENVIADO] linear=+0.93 angular=+0.10  siguiendo camino (-13 grados)
# [0069] rumbo=332 (orientation)  meta: cp#2 a 41 m, rel -9 grados  celdas BEV=2994  mapa: 3911 celdas  pose=(+0.57,-0.06,-8gr)
#   [ENVIADO] linear=+0.94 angular=+0.09  siguiendo camino (-11 grados)
# [0070] rumbo=333 (orientation)  meta: cp#2 a 41 m, rel -10 grados  celdas BEV=2994  mapa: 3748 celdas  pose=(+0.57,-0.06,-8gr)
#   [ENVIADO] linear=+0.95 angular=+0.07  siguiendo camino (-8 grados)
# [0071] rumbo=327 (orientation)  meta: cp#2 a 41 m, rel -4 grados  celdas BEV=2994  mapa: 3993 celdas  pose=(+0.59,-0.07,-8gr)
#   [ENVIADO] linear=+0.95 angular=+0.07  siguiendo camino (-9 grados)
# [0072] rumbo=329 (orientation)  meta: cp#2 a 41 m, rel -6 grados  celdas BEV=2994  mapa: 4323 celdas  pose=(+0.61,-0.07,-8gr)
#   [ENVIADO] linear=+0.96 angular=+0.06  siguiendo camino (-7 grados)
# [0073] rumbo=329 (orientation)  meta: cp#2 a 41 m, rel -6 grados  celdas BEV=2994  mapa: 4547 celdas  pose=(+0.62,-0.07,-8gr)
#   [ENVIADO] linear=+0.94 angular=+0.08  siguiendo camino (-10 grados)
# [0074] rumbo=330 (orientation)  meta: cp#2 a 40 m, rel -7 grados  celdas BEV=2994  mapa: 4547 celdas  pose=(+0.62,-0.07,-8gr)
#   [ENVIADO] linear=+0.91 angular=+0.13  siguiendo camino (-17 grados)
# [0075] rumbo=329 (orientation)  meta: cp#2 a 40 m, rel -6 grados  celdas BEV=2994  mapa: 4687 celdas  pose=(+0.66,-0.08,-8gr)
#   [ENVIADO] linear=+0.90 angular=-0.15  siguiendo camino (+19 grados)
# [0076] rumbo=324 (orientation)  meta: cp#2 a 40 m, rel -1 grados  celdas BEV=2994  mapa: 4750 celdas  pose=(+0.68,-0.08,-8gr)
#   [ENVIADO] linear=+0.88 angular=-0.17  siguiendo camino (+22 grados)
# [0077] rumbo=326 (orientation)  meta: cp#2 a 40 m, rel -3 grados  celdas BEV=2994  mapa: 4823 celdas  pose=(+0.70,-0.08,-8gr)
#   [ENVIADO] linear=+0.97 angular=+0.04  siguiendo camino (-5 grados)
# [0078] rumbo=326 (orientation)  meta: cp#2 a 40 m, rel -4 grados  celdas BEV=2994  mapa: 4834 celdas  pose=(+0.70,-0.08,-8gr)
#   [ENVIADO] linear=+0.90 angular=-0.14  siguiendo camino (+18 grados)
# [0079] rumbo=329 (orientation)  meta: cp#2 a 39 m, rel -7 grados  celdas BEV=2994  mapa: 4935 celdas  pose=(+0.72,-0.08,-8gr)
#   [ENVIADO] linear=+0.99 angular=-0.01  siguiendo camino (+1 grados)
# [0080] rumbo=332 (orientation)  meta: cp#2 a 39 m, rel -10 grados  celdas BEV=2994  mapa: 5025 celdas  pose=(+0.74,-0.09,-8gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0081] rumbo=331 (orientation)  meta: cp#2 a 38 m, rel -8 grados  celdas BEV=2994  mapa: 5090 celdas  pose=(+0.76,-0.09,-8gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0082] rumbo=331 (orientation)  meta: cp#2 a 38 m, rel -8 grados  celdas BEV=2994  mapa: 4996 celdas  pose=(+0.76,-0.09,-8gr)
# [bridge] RECUPERACION: buscando rumbo transitable (3 planes vacios seguidos)
# [bridge]   rumbo +0 grados: libre=86% cobertura=77%
# [bridge]   rumbo +90 grados: libre=97% cobertura=20%
# [bridge]   rumbo -90 grados: libre=100% cobertura=21%
# [bridge]   rumbo +180 grados: libre=0% cobertura=0%
# [bridge]   elijo rumbo +0 grados por mapa (libre=86%)
# [0083] rumbo=331 (orientation)  meta: cp#2 a 38 m, rel -8 grados  celdas BEV=2994  mapa: 4881 celdas  pose=(+0.76,-0.09,-8gr)
#   [ENVIADO] linear=+1.00 angular=-0.00  siguiendo camino (+0 grados)
# [0084] rumbo=331 (orientation)  meta: cp#2 a 38 m, rel -8 grados  celdas BEV=2994  mapa: 4907 celdas  pose=(+0.77,-0.09,-8gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0085] rumbo=334 (orientation)  meta: cp#2 a 38 m, rel -11 grados  celdas BEV=2994  mapa: 4772 celdas  pose=(+0.77,-0.09,-8gr)
#   [ENVIADO] linear=+0.93 angular=-0.10  siguiendo camino (+13 grados)
# [0086] rumbo=334 (orientation)  meta: cp#2 a 38 m, rel -11 grados  celdas BEV=2994  mapa: 4663 celdas  pose=(+0.77,-0.09,-8gr)
#   [ENVIADO] linear=+0.90 angular=-0.14  siguiendo camino (+18 grados)
# [0087] rumbo=338 (orientation)  meta: cp#2 a 37 m, rel -15 grados  celdas BEV=2994  mapa: 4588 celdas  pose=(+0.78,-0.09,-8gr)
#   [ENVIADO] linear=+0.85 angular=+0.22  siguiendo camino (-28 grados)
# [0088] rumbo=341 (orientation)  meta: cp#2 a 37 m, rel -18 grados  celdas BEV=2994  mapa: 4652 celdas  pose=(+0.80,-0.09,-8gr)
#   [ENVIADO] linear=+0.98 angular=+0.03  siguiendo camino (-4 grados)
# [0089] rumbo=338 (orientation)  meta: cp#2 a 37 m, rel -15 grados  celdas BEV=2994  mapa: 4575 celdas  pose=(+0.80,-0.09,-8gr)
#   [ENVIADO] linear=+0.99 angular=-0.02  siguiendo camino (+2 grados)
# [0090] rumbo=335 (orientation)  meta: cp#2 a 37 m, rel -12 grados  celdas BEV=2994  mapa: 4650 celdas  pose=(+0.82,-0.10,-8gr)
#   [ENVIADO] linear=+0.99 angular=-0.02  siguiendo camino (+2 grados)
# [0091] rumbo=329 (orientation)  meta: cp#2 a 37 m, rel -7 grados  celdas BEV=2994  mapa: 4706 celdas  pose=(+0.85,-0.10,-8gr)
#   [ENVIADO] linear=+1.00 angular=+0.01  siguiendo camino (-1 grados)
# [0092] rumbo=331 (orientation)  meta: cp#2 a 36 m, rel -9 grados  celdas BEV=2994  mapa: 4772 celdas  pose=(+0.87,-0.10,-8gr)
#   [ENVIADO] linear=+0.97 angular=+0.04  siguiendo camino (-5 grados)
# [0093] rumbo=330 (orientation)  meta: cp#2 a 36 m, rel -8 grados  celdas BEV=2994  mapa: 4859 celdas  pose=(+0.89,-0.11,-8gr)
#   [ENVIADO] linear=+0.97 angular=+0.04  siguiendo camino (-5 grados)
# [0094] rumbo=326 (orientation)  meta: cp#2 a 36 m, rel -4 grados  celdas BEV=2994  mapa: 4948 celdas  pose=(+0.91,-0.11,-8gr)
#   [ENVIADO] linear=+0.97 angular=-0.04  siguiendo camino (+5 grados)
# [0095] rumbo=334 (orientation)  meta: cp#2 a 36 m, rel -12 grados  celdas BEV=2994  mapa: 5038 celdas  pose=(+0.94,-0.11,-8gr)
#   [ENVIADO] linear=+1.00 angular=+0.01  siguiendo camino (-1 grados)
# [0096] rumbo=334 (orientation)  meta: cp#2 a 35 m, rel -12 grados  celdas BEV=2994  mapa: 5097 celdas  pose=(+0.96,-0.12,-8gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0097] rumbo=331 (orientation)  meta: cp#2 a 35 m, rel -9 grados  celdas BEV=2994  mapa: 5197 celdas  pose=(+0.99,-0.12,-8gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0098] rumbo=333 (orientation)  meta: cp#2 a 35 m, rel -11 grados  celdas BEV=2994  mapa: 5149 celdas  pose=(+0.99,-0.12,-8gr)
# [bridge] RECUPERACION: buscando rumbo transitable (3 planes vacios seguidos)
# [bridge]   rumbo +0 grados: libre=82% cobertura=79%
# [bridge]   rumbo +90 grados: libre=97% cobertura=21%
# [bridge]   rumbo -90 grados: libre=100% cobertura=22%
# [bridge]   rumbo +180 grados: libre=100% cobertura=0%
# [bridge]   elijo rumbo +0 grados por mapa (libre=82%)
# [0099] rumbo=333 (orientation)  meta: cp#2 a 35 m, rel -11 grados  celdas BEV=2994  mapa: 5188 celdas  pose=(+1.00,-0.12,-8gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0100] rumbo=333 (orientation)  meta: cp#2 a 35 m, rel -11 grados  celdas BEV=2994  mapa: 5116 celdas  pose=(+1.00,-0.12,-8gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0101] rumbo=332 (orientation)  meta: cp#2 a 35 m, rel -11 grados  celdas BEV=2994  mapa: 5089 celdas  pose=(+1.00,-0.12,-8gr)
# [bridge] RECUPERACION: buscando rumbo transitable (3 planes vacios seguidos)
# [bridge]   rumbo +0 grados: libre=80% cobertura=78%
# [bridge]   rumbo +90 grados: libre=93% cobertura=21%
# [bridge]   rumbo -90 grados: libre=100% cobertura=22%
# [bridge]   rumbo +180 grados: libre=100% cobertura=0%
# [bridge]   elijo rumbo +0 grados por mapa (libre=80%)
# [0102] rumbo=332 (orientation)  meta: cp#2 a 35 m, rel -11 grados  celdas BEV=2994  mapa: 4962 celdas  pose=(+1.00,-0.12,-8gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0103] rumbo=333 (orientation)  meta: cp#2 a 35 m, rel -12 grados  celdas BEV=2994  mapa: 4891 celdas  pose=(+1.00,-0.12,-8gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0104] rumbo=333 (orientation)  meta: cp#2 a 35 m, rel -12 grados  celdas BEV=2994  mapa: 4777 celdas  pose=(+1.00,-0.12,-8gr)
# [bridge] RECUPERACION: buscando rumbo transitable (3 planes vacios seguidos)
# [bridge]   rumbo +0 grados: libre=82% cobertura=74%
# [bridge]   rumbo +90 grados: libre=92% cobertura=19%
# [bridge]   rumbo -90 grados: libre=100% cobertura=20%
# [bridge]   rumbo +180 grados: libre=0% cobertura=0%
# [bridge]   elijo rumbo +0 grados por mapa (libre=82%)
# [0105] rumbo=333 (orientation)  meta: cp#2 a 35 m, rel -12 grados  celdas BEV=2994  mapa: 4659 celdas  pose=(+1.00,-0.12,-8gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0106] rumbo=333 (orientation)  meta: cp#2 a 35 m, rel -12 grados  celdas BEV=2994  mapa: 4506 celdas  pose=(+1.00,-0.12,-8gr)
#   [ENVIADO] linear=+0.76 angular=-0.35  siguiendo camino (+44 grados)
# [0107] rumbo=333 (orientation)  meta: cp#2 a 35 m, rel -12 grados  celdas BEV=2994  mapa: 4394 celdas  pose=(+1.00,-0.12,-8gr)
#   [ENVIADO] linear=+0.76 angular=-0.35  siguiendo camino (+44 grados)
# [0108] rumbo=334 (orientation)  meta: cp#2 a 35 m, rel -14 grados  celdas BEV=2994  mapa: 4492 celdas  pose=(+1.02,-0.12,-8gr)
#   [ENVIADO] linear=+0.93 angular=+0.10  siguiendo camino (-12 grados)
# [0109] rumbo=339 (orientation)  meta: cp#2 a 34 m, rel -19 grados  celdas BEV=2994  mapa: 4498 celdas  pose=(+1.03,-0.12,-8gr)
#   [ENVIADO] linear=+0.94 angular=+0.09  siguiendo camino (-11 grados)
# [0110] rumbo=339 (orientation)  meta: cp#2 a 33 m, rel -19 grados  celdas BEV=2994  mapa: 4589 celdas  pose=(+1.05,-0.13,-8gr)
#   [ENVIADO] linear=+0.94 angular=+0.09  siguiendo camino (-12 grados)
# [0111] rumbo=332 (orientation)  meta: cp#2 a 33 m, rel -13 grados  celdas BEV=2994  mapa: 4673 celdas  pose=(+1.07,-0.13,-9gr)
#   [ENVIADO] linear=+0.85 angular=+0.21  siguiendo camino (-26 grados)
# [0112] rumbo=331 (orientation)  meta: cp#2 a 32 m, rel -12 grados  celdas BEV=2994  mapa: 4755 celdas  pose=(+1.10,-0.14,-9gr)
#   [ENVIADO] linear=+0.85 angular=+0.21  siguiendo camino (-27 grados)
# [0113] rumbo=322 (orientation)  meta: cp#2 a 32 m, rel -3 grados  celdas BEV=2994  mapa: 4817 celdas  pose=(+1.12,-0.14,-9gr)
#   [ENVIADO] linear=+0.88 angular=-0.18  siguiendo camino (+22 grados)
# [0114] rumbo=323 (orientation)  meta: cp#2 a 32 m, rel -4 grados  celdas BEV=2994  mapa: 4895 celdas  pose=(+1.13,-0.14,-9gr)
# [bridge] cambio de lado justificado (-33 grados hacia izquierda)
#   [ENVIADO] linear=+0.81 angular=+0.26  siguiendo camino (-33 grados)
# [0115] rumbo=324 (orientation)  meta: cp#2 a 32 m, rel -4 grados  celdas BEV=2994  mapa: 4964 celdas  pose=(+1.15,-0.14,-9gr)
#   [ENVIADO] linear=+0.81 angular=+0.27  siguiendo camino (-34 grados)
# [0116] rumbo=311 (orientation)  meta: cp#2 a 32 m, rel +10 grados  celdas BEV=2994  mapa: 5089 celdas  pose=(+1.18,-0.15,-9gr)
# [bridge] cambio de lado justificado (+38 grados hacia derecha)
#   [ENVIADO] linear=+0.79 angular=-0.30  siguiendo camino (+38 grados)
# [0117] rumbo=314 (orientation)  meta: cp#2 a 32 m, rel +7 grados  celdas BEV=2994  mapa: 5165 celdas  pose=(+1.20,-0.15,-9gr)
#   [ENVIADO] linear=+0.79 angular=-0.30  siguiendo camino (+38 grados)
# [0118] rumbo=316 (orientation)  meta: cp#2 a 31 m, rel +6 grados  celdas BEV=2994  mapa: 5215 celdas  pose=(+1.22,-0.15,-9gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0119] rumbo=324 (orientation)  meta: cp#2 a 31 m, rel -2 grados  celdas BEV=2994  mapa: 5274 celdas  pose=(+1.23,-0.16,-9gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0120] rumbo=327 (orientation)  meta: cp#2 a 31 m, rel -5 grados  celdas BEV=2994  mapa: 5270 celdas  pose=(+1.23,-0.16,-9gr)
# [bridge] RECUPERACION: buscando rumbo transitable (3 planes vacios seguidos)
# [bridge]   rumbo +0 grados: libre=69% cobertura=80%
# [bridge]   rumbo +90 grados: libre=98% cobertura=23%
# [bridge]   rumbo -90 grados: libre=98% cobertura=22%
# [bridge]   rumbo +180 grados: libre=100% cobertura=1%
# [bridge]   elijo rumbo +0 grados por mapa (libre=69%)
# [0121] rumbo=327 (orientation)  meta: cp#2 a 31 m, rel -5 grados  celdas BEV=2994  mapa: 5196 celdas  pose=(+1.23,-0.16,-9gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0122] rumbo=327 (orientation)  meta: cp#2 a 31 m, rel -5 grados  celdas BEV=2994  mapa: 5140 celdas  pose=(+1.23,-0.16,-9gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0123] rumbo=327 (orientation)  meta: cp#2 a 31 m, rel -5 grados  celdas BEV=2994  mapa: 5098 celdas  pose=(+1.24,-0.16,-9gr)
# [bridge] RECUPERACION: buscando rumbo transitable (3 planes vacios seguidos)
# [bridge]   rumbo +0 grados: libre=72% cobertura=78%
# [bridge]   rumbo +90 grados: libre=98% cobertura=21%
# [bridge]   rumbo -90 grados: libre=98% cobertura=21%
# [bridge]   rumbo +180 grados: libre=100% cobertura=0%
# [bridge]   elijo rumbo +0 grados por mapa (libre=72%)
# [0124] rumbo=327 (orientation)  meta: cp#2 a 31 m, rel -4 grados  celdas BEV=2994  mapa: 4933 celdas  pose=(+1.24,-0.16,-9gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0125] rumbo=327 (orientation)  meta: cp#2 a 31 m, rel -4 grados  celdas BEV=2994  mapa: 4807 celdas  pose=(+1.24,-0.16,-9gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0126] rumbo=328 (orientation)  meta: cp#2 a 31 m, rel -5 grados  celdas BEV=2994  mapa: 4741 celdas  pose=(+1.24,-0.16,-9gr)
# [bridge] RECUPERACION: buscando rumbo transitable (3 planes vacios seguidos)
# [bridge]   rumbo +0 grados: libre=75% cobertura=74%
# [bridge]   rumbo +90 grados: libre=98% cobertura=19%
# [bridge]   rumbo -90 grados: libre=98% cobertura=20%
# [bridge]   rumbo +180 grados: libre=0% cobertura=0%
# [bridge]   elijo rumbo +0 grados por mapa (libre=75%)
# [0127] rumbo=326 (orientation)  meta: cp#2 a 31 m, rel -3 grados  celdas BEV=2994  mapa: 4651 celdas  pose=(+1.24,-0.16,-9gr)
#   [ENVIADO] linear=+0.88 angular=-0.17  siguiendo camino (+22 grados)
# [0128] rumbo=326 (orientation)  meta: cp#2 a 31 m, rel -3 grados  celdas BEV=2994  mapa: 4534 celdas  pose=(+1.24,-0.16,-9gr)
#   [ENVIADO] linear=+0.88 angular=-0.17  siguiendo camino (+22 grados)
# [0129] rumbo=333 (orientation)  meta: cp#2 a 31 m, rel -10 grados  celdas BEV=2994  mapa: 4640 celdas  pose=(+1.28,-0.16,-9gr)
#   [ENVIADO] linear=+0.85 angular=+0.00  mantengo el rumbo (evito titubeo, -27 grados)
# [0130] rumbo=330 (orientation)  meta: cp#2 a 31 m, rel -6 grados  celdas BEV=2994  mapa: 4655 celdas  pose=(+1.29,-0.17,-9gr)
#   [ENVIADO] linear=+0.85 angular=+0.21  siguiendo camino (-27 grados)
# [0131] rumbo=336 (orientation)  meta: cp#2 a 30 m, rel -12 grados  celdas BEV=2994  mapa: 4735 celdas  pose=(+1.33,-0.17,-9gr)
#   [ENVIADO] linear=+0.89 angular=+0.00  mantengo el rumbo (evito titubeo, +19 grados)
# [0132] rumbo=336 (orientation)  meta: cp#2 a 30 m, rel -12 grados  celdas BEV=2994  mapa: 4762 celdas  pose=(+1.35,-0.18,-10gr)
#   [ENVIADO] linear=+0.89 angular=-0.15  siguiendo camino (+19 grados)
# [0133] rumbo=335 (orientation)  meta: cp#2 a 29 m, rel -11 grados  celdas BEV=2994  mapa: 4907 celdas  pose=(+1.38,-0.18,-9gr)
#   [ENVIADO] linear=+0.89 angular=-0.15  siguiendo camino (+19 grados)
# [0134] rumbo=327 (orientation)  meta: cp#2 a 29 m, rel -3 grados  celdas BEV=2994  mapa: 4984 celdas  pose=(+1.40,-0.18,-10gr)
#   [ENVIADO] linear=+0.89 angular=-0.15  siguiendo camino (+20 grados)
# [0135] rumbo=334 (orientation)  meta: cp#2 a 28 m, rel -10 grados  celdas BEV=2994  mapa: 5065 celdas  pose=(+1.41,-0.19,-10gr)
#   [ENVIADO] linear=+0.90 angular=-0.14  siguiendo camino (+18 grados)
# [0136] rumbo=335 (orientation)  meta: cp#2 a 28 m, rel -10 grados  celdas BEV=2994  mapa: 5103 celdas  pose=(+1.44,-0.19,-10gr)
#   [ENVIADO] linear=+0.90 angular=-0.14  siguiendo camino (+17 grados)
# [0137] rumbo=354 (orientation)  meta: cp#2 a 28 m, rel -29 grados  celdas BEV=2994  mapa: 5238 celdas  pose=(+1.46,-0.19,-16gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0138] rumbo=347 (orientation)  meta: cp#2 a 28 m, rel -22 grados  celdas BEV=2994  mapa: 5299 celdas  pose=(+1.47,-0.20,-16gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0139] rumbo=348 (orientation)  meta: cp#2 a 28 m, rel -23 grados  celdas BEV=2994  mapa: 5291 celdas  pose=(+1.47,-0.20,-16gr)
# [bridge] RECUPERACION: buscando rumbo transitable (3 planes vacios seguidos)
# [bridge]   rumbo +0 grados: libre=83% cobertura=79%
# [bridge]   rumbo +90 grados: libre=84% cobertura=26%
# [bridge]   rumbo -90 grados: libre=96% cobertura=20%
# [bridge]   rumbo +180 grados: libre=100% cobertura=1%
# [bridge]   elijo rumbo +90 grados por mapa (libre=84%)
#   [ENVIADO] linear=+0.00 angular=-0.45  girando hacia +90 grados (regimen cercano)
# [bridge]   frente libre por mapa tras girar +45 grados, corto
#   [ENVIADO] linear=+0.00 angular=+0.00  fin del giro
# [0140] rumbo=348 (orientation)  meta: cp#2 a 28 m, rel -23 grados  celdas BEV=2994  mapa: 5264 celdas  pose=(+1.47,-0.20,-16gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0141] rumbo=348 (orientation)  meta: cp#2 a 28 m, rel -24 grados  celdas BEV=2994  mapa: 5231 celdas  pose=(+1.47,-0.20,-16gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0142] rumbo=347 (orientation)  meta: cp#2 a 28 m, rel -23 grados  celdas BEV=2994  mapa: 5121 celdas  pose=(+1.47,-0.20,-16gr)
# [bridge] RECUPERACION: buscando rumbo transitable (3 planes vacios seguidos)
# [bridge]   rumbo +0 grados: libre=88% cobertura=78%
# [bridge]   rumbo +90 grados: libre=88% cobertura=25%
# [bridge]   rumbo -90 grados: libre=96% cobertura=19%
# [bridge]   rumbo +180 grados: libre=100% cobertura=0%
# [bridge]   elijo rumbo +90 grados por mapa (libre=88%)
#   [ENVIADO] linear=+0.00 angular=-0.45  girando hacia +90 grados (regimen cercano)
# [bridge]   frente libre por mapa tras girar +45 grados, corto
#   [ENVIADO] linear=+0.00 angular=+0.00  fin del giro
# [0143] rumbo=353 (orientation)  meta: cp#2 a 28 m, rel -29 grados  celdas BEV=2994  mapa: 5082 celdas  pose=(+1.47,-0.20,-17gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0144] rumbo=349 (orientation)  meta: cp#2 a 28 m, rel -25 grados  celdas BEV=2994  mapa: 4951 celdas  pose=(+1.47,-0.20,-17gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0145] rumbo=348 (orientation)  meta: cp#2 a 28 m, rel -25 grados  celdas BEV=2994  mapa: 4854 celdas  pose=(+1.47,-0.20,-17gr)
#   [ENVIADO] linear=+0.99 angular=+0.01  siguiendo camino (-1 grados)
# [0146] rumbo=348 (orientation)  meta: cp#2 a 28 m, rel -25 grados  celdas BEV=2994  mapa: 4713 celdas  pose=(+1.47,-0.20,-17gr)
#   [ENVIADO] linear=+0.99 angular=+0.01  siguiendo camino (-1 grados)
# [0147] rumbo=356 (orientation)  meta: cp#2 a 28 m, rel -33 grados  celdas BEV=2994  mapa: 4711 celdas  pose=(+1.48,-0.20,-18gr)
#   [ENVIADO] linear=+0.87 angular=+0.19  siguiendo camino (-24 grados)
# [0148] rumbo=356 (orientation)  meta: cp#2 a 28 m, rel -34 grados  celdas BEV=2994  mapa: 4768 celdas  pose=(+1.52,-0.21,-18gr)
#   [ENVIADO] linear=+0.85 angular=+0.22  siguiendo camino (-28 grados)
# [0149] rumbo=355 (orientation)  meta: cp#2 a 28 m, rel -33 grados  celdas BEV=2994  mapa: 4615 celdas  pose=(+1.54,-0.22,-18gr)
#   [ENVIADO] linear=+0.85 angular=+0.21  siguiendo camino (-26 grados)
# [0150] rumbo=352 (orientation)  meta: cp#2 a 28 m, rel -30 grados  celdas BEV=2994  mapa: 4714 celdas  pose=(+1.56,-0.22,-18gr)
#   [ENVIADO] linear=+0.87 angular=+0.18  siguiendo camino (-23 grados)
# [0151] rumbo=346 (orientation)  meta: cp#2 a 28 m, rel -25 grados  celdas BEV=2994  mapa: 4805 celdas  pose=(+1.57,-0.23,-18gr)
#   [ENVIADO] linear=+0.88 angular=+0.17  siguiendo camino (-22 grados)
# [0152] rumbo=346 (orientation)  meta: cp#2 a 28 m, rel -26 grados  celdas BEV=2994  mapa: 4921 celdas  pose=(+1.59,-0.23,-18gr)
#   [ENVIADO] linear=+0.88 angular=+0.17  siguiendo camino (-22 grados)
# [0153] rumbo=340 (orientation)  meta: cp#2 a 27 m, rel -20 grados  celdas BEV=2994  mapa: 5059 celdas  pose=(+1.66,-0.26,-19gr)
#   [ENVIADO] linear=+0.83 angular=+0.24  siguiendo camino (-30 grados)
# [0154] rumbo=329 (orientation)  meta: cp#2 a 27 m, rel -9 grados  celdas BEV=2994  mapa: 5156 celdas  pose=(+1.68,-0.26,-17gr)
#   [ENVIADO] linear=+0.84 angular=+0.23  siguiendo camino (-29 grados)
# [0155] rumbo=324 (orientation)  meta: cp#2 a 27 m, rel -5 grados  celdas BEV=2994  mapa: 5161 celdas  pose=(+1.70,-0.27,-18gr)
#   [ENVIADO] linear=+0.86 angular=+0.20  siguiendo camino (-25 grados)
# [0156] rumbo=324 (orientation)  meta: cp#2 a 26 m, rel -5 grados  celdas BEV=2994  mapa: 5329 celdas  pose=(+1.73,-0.28,-18gr)
#   [ENVIADO] linear=+0.86 angular=+0.20  siguiendo camino (-26 grados)
# [0157] rumbo=323 (orientation)  meta: cp#2 a 26 m, rel -5 grados  celdas BEV=2994  mapa: 5400 celdas  pose=(+1.75,-0.29,-18gr)
#   [ENVIADO] linear=+0.96 angular=+0.06  siguiendo camino (-7 grados)
# [0158] rumbo=316 (orientation)  meta: cp#2 a 25 m, rel +3 grados  celdas BEV=2994  mapa: 5479 celdas  pose=(+1.77,-0.29,-18gr)
#   [ENVIADO] linear=+0.96 angular=+0.06  siguiendo camino (-7 grados)
# [0159] rumbo=315 (orientation)  meta: cp#2 a 24 m, rel +4 grados  celdas BEV=2994  mapa: 5531 celdas  pose=(+1.80,-0.30,-19gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0160] rumbo=322 (orientation)  meta: cp#2 a 23 m, rel -3 grados  celdas BEV=2994  mapa: 5496 celdas  pose=(+1.83,-0.31,-18gr)
#   [ENVIADO] linear=+1.00 angular=-0.00  siguiendo camino (+0 grados)
# [0161] rumbo=322 (orientation)  meta: cp#2 a 23 m, rel -3 grados  celdas BEV=2994  mapa: 5417 celdas  pose=(+1.83,-0.31,-18gr)
#   [ENVIADO] linear=+1.00 angular=-0.00  siguiendo camino (+0 grados)
# [0162] rumbo=314 (orientation)  meta: cp#2 a 23 m, rel +6 grados  celdas BEV=2994  mapa: 5394 celdas  pose=(+1.85,-0.32,-19gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0163] rumbo=316 (orientation)  meta: cp#2 a 22 m, rel +6 grados  celdas BEV=2994  mapa: 5415 celdas  pose=(+1.88,-0.33,-19gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0164] rumbo=321 (orientation)  meta: cp#2 a 22 m, rel +1 grados  celdas BEV=2994  mapa: 5393 celdas  pose=(+1.88,-0.33,-19gr)
# [bridge] RECUPERACION: buscando rumbo transitable (3 planes vacios seguidos)
# [bridge]   rumbo +0 grados: libre=81% cobertura=82%
# [bridge]   rumbo +90 grados: libre=92% cobertura=25%
# [bridge]   rumbo -90 grados: libre=99% cobertura=26%
# [bridge]   rumbo +180 grados: libre=100% cobertura=2%
# [bridge]   elijo rumbo -90 grados por mapa (libre=99%)
#   [ENVIADO] linear=+0.00 angular=+0.45  girando hacia -90 grados (regimen cercano)
# [bridge]   frente libre por mapa tras girar -45 grados, corto
#   [ENVIADO] linear=+0.00 angular=+0.00  fin del giro
# [0165] rumbo=321 (orientation)  meta: cp#2 a 22 m, rel +2 grados  celdas BEV=2994  mapa: 5060 celdas  pose=(+1.88,-0.33,-19gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0166] rumbo=321 (orientation)  meta: cp#2 a 22 m, rel +2 grados  celdas BEV=2994  mapa: 4951 celdas  pose=(+1.88,-0.33,-19gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0167] rumbo=321 (orientation)  meta: cp#2 a 22 m, rel +2 grados  celdas BEV=2994  mapa: 4830 celdas  pose=(+1.88,-0.33,-19gr)
# [bridge] RECUPERACION: buscando rumbo transitable (3 planes vacios seguidos)
# [bridge]   rumbo +0 grados: libre=82% cobertura=76%
# [bridge]   rumbo +90 grados: libre=89% cobertura=21%
# [bridge]   rumbo -90 grados: libre=100% cobertura=21%
# [bridge]   rumbo +180 grados: libre=100% cobertura=0%
# [bridge]   elijo rumbo +0 grados por mapa (libre=82%)
# [0168] rumbo=321 (orientation)  meta: cp#2 a 22 m, rel +2 grados  celdas BEV=2994  mapa: 4712 celdas  pose=(+1.88,-0.33,-19gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0169] rumbo=321 (orientation)  meta: cp#2 a 22 m, rel +1 grados  celdas BEV=2994  mapa: 4614 celdas  pose=(+1.88,-0.33,-19gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0170] rumbo=321 (orientation)  meta: cp#2 a 22 m, rel +1 grados  celdas BEV=2994  mapa: 4434 celdas  pose=(+1.88,-0.33,-19gr)
# [bridge] RECUPERACION: buscando rumbo transitable (3 planes vacios seguidos)
# [bridge]   rumbo +0 grados: libre=86% cobertura=71%
# [bridge]   rumbo +90 grados: libre=88% cobertura=18%
# [bridge]   rumbo -90 grados: libre=100% cobertura=20%
# [bridge]   rumbo +180 grados: libre=0% cobertura=0%
# [bridge]   elijo rumbo +0 grados por mapa (libre=86%)
# [0171] rumbo=321 (orientation)  meta: cp#2 a 22 m, rel +1 grados  celdas BEV=2994  mapa: 4414 celdas  pose=(+1.88,-0.33,-19gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0172] rumbo=321 (orientation)  meta: cp#2 a 22 m, rel +1 grados  celdas BEV=2994  mapa: 4119 celdas  pose=(+1.88,-0.33,-19gr)
#   [ENVIADO] linear=+0.96 angular=+0.05  siguiendo camino (-7 grados)
# [0173] rumbo=321 (orientation)  meta: cp#2 a 22 m, rel +1 grados  celdas BEV=2994  mapa: 4020 celdas  pose=(+1.88,-0.33,-19gr)
#   [ENVIADO] linear=+0.96 angular=+0.05  siguiendo camino (-7 grados)
# [0174] rumbo=318 (orientation)  meta: cp#2 a 22 m, rel +4 grados  celdas BEV=2994  mapa: 3846 celdas  pose=(+1.89,-0.33,-19gr)
#   [ENVIADO] linear=+0.97 angular=-0.05  siguiendo camino (+6 grados)
# [0175] rumbo=325 (orientation)  meta: cp#2 a 22 m, rel -3 grados  celdas BEV=2994  mapa: 3824 celdas  pose=(+1.91,-0.34,-19gr)
#   [ENVIADO] linear=+0.93 angular=-0.10  siguiendo camino (+13 grados)
# [0176] rumbo=316 (orientation)  meta: cp#2 a 22 m, rel +6 grados  celdas BEV=2994  mapa: 4146 celdas  pose=(+1.93,-0.35,-19gr)
#   [ENVIADO] linear=+0.93 angular=-0.10  siguiendo camino (+13 grados)
# [0177] rumbo=318 (orientation)  meta: cp#2 a 21 m, rel +5 grados  celdas BEV=2994  mapa: 4307 celdas  pose=(+1.96,-0.36,-18gr)
#   [ENVIADO] linear=+0.96 angular=-0.06  siguiendo camino (+7 grados)
# [0178] rumbo=328 (orientation)  meta: cp#2 a 20 m, rel -5 grados  celdas BEV=2994  mapa: 4388 celdas  pose=(+1.98,-0.36,-18gr)
#   [ENVIADO] linear=+0.98 angular=+0.03  siguiendo camino (-4 grados)
# [0179] rumbo=327 (orientation)  meta: cp#2 a 20 m, rel -4 grados  celdas BEV=2994  mapa: 4472 celdas  pose=(+2.00,-0.37,-18gr)
#   [ENVIADO] linear=+0.96 angular=+0.05  siguiendo camino (-6 grados)
# [0180] rumbo=319 (orientation)  meta: cp#2 a 20 m, rel +4 grados  celdas BEV=2994  mapa: 4608 celdas  pose=(+2.03,-0.38,-18gr)
#   [ENVIADO] linear=+0.96 angular=+0.05  siguiendo camino (-6 grados)
# [0181] rumbo=321 (orientation)  meta: cp#2 a 19 m, rel +2 grados  celdas BEV=2994  mapa: 4667 celdas  pose=(+2.05,-0.39,-18gr)
#   [ENVIADO] linear=+0.98 angular=-0.03  siguiendo camino (+3 grados)
# [0182] rumbo=314 (orientation)  meta: cp#2 a 19 m, rel +9 grados  celdas BEV=2994  mapa: 4717 celdas  pose=(+2.07,-0.39,-18gr)
#   [ENVIADO] linear=+0.95 angular=-0.07  siguiendo camino (+9 grados)
# [0183] rumbo=319 (orientation)  meta: cp#2 a 19 m, rel +3 grados  celdas BEV=2994  mapa: 4783 celdas  pose=(+2.11,-0.41,-18gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0184] rumbo=326 (orientation)  meta: cp#2 a 18 m, rel -4 grados  celdas BEV=2994  mapa: 4844 celdas  pose=(+2.15,-0.42,-18gr)
#   [ENVIADO] linear=+0.99 angular=+0.01  siguiendo camino (-2 grados)
# [0185] rumbo=327 (orientation)  meta: cp#2 a 18 m, rel -5 grados  celdas BEV=2994  mapa: 4828 celdas  pose=(+2.15,-0.42,-18gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0186] rumbo=320 (orientation)  meta: cp#2 a 17 m, rel +2 grados  celdas BEV=2994  mapa: 4872 celdas  pose=(+2.17,-0.43,-18gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0187] rumbo=326 (orientation)  meta: cp#2 a 17 m, rel -4 grados  celdas BEV=2994  mapa: 4791 celdas  pose=(+2.17,-0.43,-18gr)
# [bridge] RECUPERACION: buscando rumbo transitable (3 planes vacios seguidos)
# [bridge]   rumbo +0 grados: libre=86% cobertura=75%
# [bridge]   rumbo +90 grados: libre=87% cobertura=22%
# [bridge]   rumbo -90 grados: libre=100% cobertura=25%
# [bridge]   rumbo +180 grados: libre=100% cobertura=1%
# [bridge]   elijo rumbo -90 grados por mapa (libre=100%)
#   [ENVIADO] linear=+0.00 angular=+0.45  girando hacia -90 grados (regimen cercano)
# [bridge]   frente libre por mapa tras girar -45 grados, corto
#   [ENVIADO] linear=+0.00 angular=+0.00  fin del giro
# [0188] rumbo=326 (orientation)  meta: cp#2 a 17 m, rel -3 grados  celdas BEV=2994  mapa: 4677 celdas  pose=(+2.17,-0.43,-18gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0189] rumbo=326 (orientation)  meta: cp#2 a 17 m, rel -4 grados  celdas BEV=2994  mapa: 4569 celdas  pose=(+2.17,-0.43,-18gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0190] rumbo=326 (orientation)  meta: cp#2 a 17 m, rel -4 grados  celdas BEV=2994  mapa: 4481 celdas  pose=(+2.17,-0.43,-18gr)
# [bridge] RECUPERACION: buscando rumbo transitable (3 planes vacios seguidos)
# [bridge]   rumbo +0 grados: libre=89% cobertura=72%
# [bridge]   rumbo +90 grados: libre=91% cobertura=21%
# [bridge]   rumbo -90 grados: libre=100% cobertura=22%
# [bridge]   rumbo +180 grados: libre=100% cobertura=0%
# [bridge]   elijo rumbo +0 grados por mapa (libre=89%)
# [0191] rumbo=328 (orientation)  meta: cp#2 a 17 m, rel -6 grados  celdas BEV=2994  mapa: 4339 celdas  pose=(+2.17,-0.43,-18gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0192] rumbo=327 (orientation)  meta: cp#2 a 17 m, rel -5 grados  celdas BEV=2994  mapa: 4225 celdas  pose=(+2.17,-0.43,-18gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0193] rumbo=327 (orientation)  meta: cp#2 a 17 m, rel -5 grados  celdas BEV=2994  mapa: 4139 celdas  pose=(+2.17,-0.43,-18gr)
# [bridge] RECUPERACION: buscando rumbo transitable (3 planes vacios seguidos)
# [bridge]   rumbo +0 grados: libre=88% cobertura=68%
# [bridge]   rumbo +90 grados: libre=90% cobertura=19%
# [bridge]   rumbo -90 grados: libre=100% cobertura=20%
# [bridge]   rumbo +180 grados: libre=0% cobertura=0%
# [bridge]   elijo rumbo +0 grados por mapa (libre=88%)
# [0194] rumbo=328 (orientation)  meta: cp#2 a 17 m, rel -6 grados  celdas BEV=2994  mapa: 3978 celdas  pose=(+2.17,-0.43,-18gr)
#   [ENVIADO] linear=+0.73 angular=-0.38  siguiendo camino (+48 grados)
# [0195] rumbo=328 (orientation)  meta: cp#2 a 17 m, rel -6 grados  celdas BEV=2994  mapa: 3757 celdas  pose=(+2.17,-0.43,-18gr)
#   [ENVIADO] linear=+0.73 angular=-0.38  siguiendo camino (+48 grados)
# [0196] rumbo=324 (orientation)  meta: cp#2 a 17 m, rel -2 grados  celdas BEV=2994  mapa: 3810 celdas  pose=(+2.18,-0.43,-18gr)
#   [ENVIADO] linear=+0.99 angular=+0.02  siguiendo camino (-3 grados)
# [0197] rumbo=333 (orientation)  meta: cp#2 a 17 m, rel -11 grados  celdas BEV=2994  mapa: 3734 celdas  pose=(+2.19,-0.43,-18gr)
#   [ENVIADO] linear=+0.93 angular=+0.10  siguiendo camino (-13 grados)
# [0198] rumbo=330 (orientation)  meta: cp#2 a 16 m, rel -8 grados  celdas BEV=2994  mapa: 3753 celdas  pose=(+2.22,-0.44,-18gr)
#   [ENVIADO] linear=+0.93 angular=+0.10  siguiendo camino (-13 grados)
# [0199] rumbo=333 (orientation)  meta: cp#2 a 16 m, rel -12 grados  celdas BEV=2994  mapa: 3755 celdas  pose=(+2.22,-0.44,-18gr)
#   [ENVIADO] linear=+0.92 angular=+0.11  siguiendo camino (-14 grados)
# [0200] rumbo=330 (orientation)  meta: cp#2 a 15 m, rel -8 grados  celdas BEV=2994  mapa: 3879 celdas  pose=(+2.24,-0.45,-18gr)
#   [ENVIADO] linear=+0.94 angular=+0.00  mantengo el rumbo (evito titubeo, +11 grados)
# [bridge] ✓ checkpoint #2 conseguido: {'message': 'Checkpoint reached successfully', 'next_checkpoint_sequence': 3, 'mission_completed': False}
# [0201] rumbo=322 (orientation)  meta: cp#2 a 15 m, rel +1 grados  celdas BEV=2994  mapa: 3969 celdas  pose=(+2.27,-0.46,-18gr)
#   [ENVIADO] linear=+0.94 angular=-0.09  siguiendo camino (+11 grados)
# [0202] rumbo=326 (orientation)  meta: cp#3 a 54 m, rel +72 grados  celdas BEV=2994  mapa: 3969 celdas  pose=(+2.27,-0.46,-18gr)
#   [ENVIADO] linear=+0.66 angular=-0.45  siguiendo camino (+60 grados)
# [0203] rumbo=323 (orientation)  meta: cp#3 a 54 m, rel +75 grados  celdas BEV=2994  mapa: 4019 celdas  pose=(+2.29,-0.46,-18gr)
#   [ENVIADO] linear=+0.66 angular=-0.45  siguiendo camino (+61 grados)
# [0204] rumbo=347 (orientation)  meta: cp#3 a 54 m, rel +51 grados  celdas BEV=2994  mapa: 4051 celdas  pose=(+2.30,-0.47,-22gr)
#   [ENVIADO] linear=+0.97 angular=-0.04  siguiendo camino (+5 grados)
# [0205] rumbo=340 (orientation)  meta: cp#3 a 54 m, rel +58 grados  celdas BEV=2994  mapa: 4059 celdas  pose=(+2.31,-0.47,-22gr)
#   [ENVIADO] linear=+0.87 angular=-0.18  siguiendo camino (+23 grados)
# [0206] rumbo=335 (orientation)  meta: cp#3 a 53 m, rel +64 grados  celdas BEV=2994  mapa: 4072 celdas  pose=(+2.33,-0.48,-22gr)
#   [ENVIADO] linear=+0.87 angular=-0.18  siguiendo camino (+24 grados)
# [0207] rumbo=335 (orientation)  meta: cp#3 a 53 m, rel +64 grados  celdas BEV=2994  mapa: 4102 celdas  pose=(+2.36,-0.49,-22gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0208] rumbo=346 (orientation)  meta: cp#3 a 53 m, rel +54 grados  celdas BEV=2994  mapa: 4106 celdas  pose=(+2.37,-0.50,-23gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0209] rumbo=345 (orientation)  meta: cp#3 a 53 m, rel +55 grados  celdas BEV=2994  mapa: 4061 celdas  pose=(+2.37,-0.50,-23gr)
# [bridge] RECUPERACION: buscando rumbo transitable (3 planes vacios seguidos)
# [bridge]   rumbo +0 grados: libre=85% cobertura=66%
# [bridge]   rumbo +90 grados: libre=100% cobertura=24%
# [bridge]   rumbo -90 grados: libre=100% cobertura=19%
# [bridge]   rumbo +180 grados: libre=100% cobertura=0%
# [bridge]   elijo rumbo +0 grados por mapa (libre=85%)
# [0210] rumbo=345 (orientation)  meta: cp#3 a 52 m, rel +55 grados  celdas BEV=2994  mapa: 3993 celdas  pose=(+2.38,-0.50,-23gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0211] rumbo=345 (orientation)  meta: cp#3 a 52 m, rel +55 grados  celdas BEV=2994  mapa: 3975 celdas  pose=(+2.38,-0.50,-23gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0212] rumbo=345 (orientation)  meta: cp#3 a 52 m, rel +55 grados  celdas BEV=2994  mapa: 3915 celdas  pose=(+2.38,-0.50,-23gr)
# [bridge] RECUPERACION: buscando rumbo transitable (3 planes vacios seguidos)
# [bridge]   rumbo +0 grados: libre=85% cobertura=64%
# [bridge]   rumbo +90 grados: libre=100% cobertura=22%
# [bridge]   rumbo -90 grados: libre=100% cobertura=18%
# [bridge]   rumbo +180 grados: libre=0% cobertura=0%
# [bridge]   elijo rumbo +0 grados por mapa (libre=85%)
# [0213] rumbo=345 (orientation)  meta: cp#3 a 52 m, rel +55 grados  celdas BEV=2994  mapa: 3841 celdas  pose=(+2.38,-0.50,-23gr)
#   [ENVIADO] linear=+0.80 angular=-0.29  siguiendo camino (+36 grados)
# [0214] rumbo=345 (orientation)  meta: cp#3 a 52 m, rel +55 grados  celdas BEV=2994  mapa: 3827 celdas  pose=(+2.38,-0.50,-23gr)
#   [ENVIADO] linear=+0.80 angular=-0.29  siguiendo camino (+36 grados)
# [0215] rumbo=346 (orientation)  meta: cp#3 a 52 m, rel +54 grados  celdas BEV=2994  mapa: 3848 celdas  pose=(+2.39,-0.51,-24gr)
#   [ENVIADO] linear=+0.78 angular=-0.31  siguiendo camino (+40 grados)
# [0216] rumbo=349 (orientation)  meta: cp#3 a 52 m, rel +50 grados  celdas BEV=2994  mapa: 3821 celdas  pose=(+2.41,-0.51,-24gr)
#   [ENVIADO] linear=+0.78 angular=-0.32  siguiendo camino (+40 grados)
# [0217] rumbo=355 (orientation)  meta: cp#3 a 52 m, rel +45 grados  celdas BEV=2994  mapa: 3714 celdas  pose=(+2.42,-0.52,-24gr)
#   [ENVIADO] linear=+0.79 angular=-0.30  siguiendo camino (+38 grados)
# [0218] rumbo=0 (orientation)  meta: cp#3 a 51 m, rel +40 grados  celdas BEV=2994  mapa: 3728 celdas  pose=(+2.45,-0.53,-24gr)
#   [ENVIADO] linear=+0.79 angular=-0.30  siguiendo camino (+39 grados)
# [0219] rumbo=6 (orientation)  meta: cp#3 a 51 m, rel +34 grados  celdas BEV=2994  mapa: 3695 celdas  pose=(+2.46,-0.54,-24gr)
#   [ENVIADO] linear=+0.79 angular=-0.30  siguiendo camino (+38 grados)
# [0220] rumbo=7 (orientation)  meta: cp#3 a 50 m, rel +33 grados  celdas BEV=2994  mapa: 3643 celdas  pose=(+2.48,-0.54,-24gr)
#   [ENVIADO] linear=+0.79 angular=-0.30  siguiendo camino (+38 grados)
# [0221] rumbo=18 (orientation)  meta: cp#3 a 50 m, rel +22 grados  celdas BEV=2994  mapa: 3593 celdas  pose=(+2.50,-0.55,-26gr)
#   [ENVIADO] linear=+0.81 angular=-0.27  siguiendo camino (+35 grados)
# [0222] rumbo=11 (orientation)  meta: cp#3 a 50 m, rel +29 grados  celdas BEV=2994  mapa: 2741 celdas  pose=(+2.51,-0.56,-26gr)
#   [ENVIADO] linear=+0.81 angular=-0.27  siguiendo camino (+35 grados)
# [0223] rumbo=31 (orientation)  meta: cp#3 a 51 m, rel +8 grados  celdas BEV=2994  mapa: 3604 celdas  pose=(+2.52,-0.56,-24gr)
#   [ENVIADO] linear=+0.93 angular=-0.10  siguiendo camino (+13 grados)
# [0224] rumbo=45 (orientation)  meta: cp#3 a 50 m, rel -6 grados  celdas BEV=2994  mapa: 4209 celdas  pose=(+2.55,-0.58,-24gr)
#   [ENVIADO] linear=+0.93 angular=-0.11  siguiendo camino (+13 grados)
# [0225] rumbo=20 (orientation)  meta: cp#3 a 50 m, rel +19 grados  celdas BEV=2994  mapa: 4425 celdas  pose=(+2.57,-0.58,-24gr)
#   [ENVIADO] linear=+0.58 angular=-0.45  siguiendo camino (+75 grados)
# [0226] rumbo=12 (orientation)  meta: cp#3 a 50 m, rel +27 grados  celdas BEV=2994  mapa: 4541 celdas  pose=(+2.58,-0.59,-24gr)
#   [ENVIADO] linear=+0.58 angular=-0.45  siguiendo camino (+76 grados)
# [0227] rumbo=11 (orientation)  meta: cp#3 a 50 m, rel +28 grados  celdas BEV=2994  mapa: 4633 celdas  pose=(+2.58,-0.59,-25gr)
#   [ENVIADO] linear=+0.58 angular=-0.45  siguiendo camino (+75 grados)
# [0228] rumbo=12 (orientation)  meta: cp#3 a 50 m, rel +27 grados  celdas BEV=2994  mapa: 4695 celdas  pose=(+2.59,-0.60,-24gr)
#   [ENVIADO] linear=+0.58 angular=-0.45  siguiendo camino (+76 grados)
# [0229] rumbo=43 (orientation)  meta: cp#3 a 50 m, rel -4 grados  celdas BEV=2994  mapa: 4745 celdas  pose=(+2.60,-0.60,-24gr)
# [bridge] cambio de lado justificado (-68 grados hacia izquierda)
#   [ENVIADO] linear=+0.62 angular=+0.45  siguiendo camino (-68 grados)
# [0230] rumbo=14 (orientation)  meta: cp#3 a 50 m, rel +25 grados  celdas BEV=2994  mapa: 4677 celdas  pose=(+2.61,-0.60,-24gr)
#   [ENVIADO] linear=+0.62 angular=+0.45  siguiendo camino (-68 grados)
# [0231] rumbo=15 (orientation)  meta: cp#3 a 50 m, rel +24 grados  celdas BEV=2994  mapa: 4703 celdas  pose=(+2.62,-0.61,-27gr)
# [bridge] cambio de lado justificado (+67 grados hacia derecha)
#   [ENVIADO] linear=+0.63 angular=-0.45  siguiendo camino (+67 grados)
# [0232] rumbo=11 (orientation)  meta: cp#3 a 50 m, rel +28 grados  celdas BEV=2994  mapa: 4690 celdas  pose=(+2.63,-0.61,-27gr)
#   [ENVIADO] linear=+0.63 angular=-0.45  siguiendo camino (+67 grados)
# [0233] rumbo=12 (orientation)  meta: cp#3 a 50 m, rel +28 grados  celdas BEV=2994  mapa: 4728 celdas  pose=(+2.63,-0.61,-27gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0234] rumbo=11 (orientation)  meta: cp#3 a 50 m, rel +28 grados  celdas BEV=2994  mapa: 4766 celdas  pose=(+2.64,-0.62,-27gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  el planner no encontro camino
# [0235] rumbo=11 (orientation)  meta: cp#3 a 50 m, rel +29 grados  celdas BEV=2994  mapa: 4765 celdas  pose=(+2.64,-0.62,-27gr)
# [bridge] RECUPERACION: buscando rumbo transitable (3 planes vacios seguidos)
# [bridge]   rumbo +0 grados: libre=26% cobertura=74%
# [bridge]   rumbo +90 grados: libre=43% cobertura=19%
# [bridge]   rumbo -90 grados: libre=54% cobertura=19%
# [bridge]   rumbo +180 grados: libre=0% cobertura=0%
# [bridge]   elijo rumbo +0 grados por mapa (libre=26%)
# [0236] rumbo=11 (orientation)  meta: cp#3 a 50 m, rel +29 grados  celdas BEV=2994  mapa: 4700 celdas  pose=(+2.64,-0.62,-27gr)
#   [ENVIADO] linear=+0.68 angular=-0.45  siguiendo camino (+58 grados)
# [0237] rumbo=11 (orientation)  meta: cp#3 a 50 m, rel +29 grados  celdas BEV=2994  mapa: 4671 celdas  pose=(+2.64,-0.62,-27gr)
#   [ENVIADO] linear=+0.68 angular=-0.45  siguiendo camino (+58 grados)
# [0238] rumbo=10 (orientation)  meta: cp#3 a 51 m, rel +29 grados  celdas BEV=2994  mapa: 4586 celdas  pose=(+2.64,-0.62,-27gr)
# [bridge] cambio de lado justificado (-74 grados hacia izquierda)
#   [ENVIADO] linear=+0.59 angular=+0.45  siguiendo camino (-74 grados)
# [0239] rumbo=7 (orientation)  meta: cp#3 a 51 m, rel +32 grados  celdas BEV=2994  mapa: 4624 celdas  pose=(+2.65,-0.62,-26gr)
#   [ENVIADO] linear=+0.59 angular=+0.45  siguiendo camino (-74 grados)
# [0240] rumbo=6 (orientation)  meta: cp#3 a 51 m, rel +33 grados  celdas BEV=2994  mapa: 4658 celdas  pose=(+2.66,-0.63,-26gr)
# [bridge] cambio de lado justificado (+75 grados hacia derecha)
#   [ENVIADO] linear=+0.58 angular=-0.45  siguiendo camino (+75 grados)
# [0241] rumbo=5 (orientation)  meta: cp#3 a 51 m, rel +34 grados  celdas BEV=2994  mapa: 4758 celdas  pose=(+2.67,-0.63,-29gr)
#   [ENVIADO] linear=+0.60 angular=-0.45  siguiendo camino (+72 grados)
# [0242] rumbo=8 (orientation)  meta: cp#3 a 51 m, rel +31 grados  celdas BEV=2994  mapa: 4783 celdas  pose=(+2.67,-0.63,-29gr)
#   [ENVIADO] linear=+0.00 angular=+0.00  OBSTACULO al frente
# [0243] rumbo=8 (orientation)  meta: cp#3 a 51 m, rel +31 grados  celdas BEV=2994  mapa: 4803 celdas  pose=(+2.68,-0.64,-30gr)
#   [ENVIADO] linear=+0.68 angular=-0.45  siguiendo camino (+58 grados)
# [0244] rumbo=7 (orientation)  meta: cp#3 a 51 m, rel +32 grados  celdas BEV=2994  mapa: 4647 celdas  pose=(+2.68,-0.64,-30gr)
#   [ENVIADO] linear=+0.68 angular=-0.45  siguiendo camino (+58 grados)
# [0245] rumbo=36 (orientation)  meta: cp#3 a 51 m, rel +3 grados  celdas BEV=2994  mapa: 4736 celdas  pose=(+2.74,-0.67,-29gr)
# [bridge] cambio de lado justificado (-74 grados hacia izquierda)
#   [ENVIADO] linear=+0.59 angular=+0.45  siguiendo camino (-74 grados)
# [0246] rumbo=5 (orientation)  meta: cp#3 a 51 m, rel +34 grados  celdas BEV=2994  mapa: 4773 celdas  pose=(+2.75,-0.67,-29gr)
#   [ENVIADO] linear=+0.59 angular=+0.45  siguiendo camino (-74 grados)
# [0247] rumbo=4 (orientation)  meta: cp#3 a 51 m, rel +35 grados  celdas BEV=2994  mapa: 4794 celdas  pose=(+2.76,-0.68,-30gr)
# '''
