# %%
from pathlib import Path
import sys

# Agrega la carpeta raíz del proyecto al path de Python de forma dinámica
sys.path.append(str(Path.cwd().parent))

# %%
# !pip install huggingface_hub pandas pyarrow
# Out:
# Collecting huggingface_hub
#   Downloading huggingface_hub-1.32.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: pandas in /home/pablolube/IROS26-LaRovernetta/.venv/lib/python3.10/site-packages (2.3.3)
# Collecting pyarrow
#   Downloading pyarrow-25.0.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /home/pablolube/IROS26-LaRovernetta/.venv/lib/python3.10/site-packages (from huggingface_hub) (8.5.0)
# Requirement already satisfied: filelock>=3.10.0 in /home/pablolube/IROS26-LaRovernetta/.venv/lib/python3.10/site-packages (from huggingface_hub) (3.32.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/pablolube/IROS26-LaRovernetta/.venv/lib/python3.10/site-packages (from huggingface_hub) (2026.7.0)
# Collecting hf-xet<2.0.0,>=1.5.2 (from huggingface_hub)
#   Downloading hf_xet-1.6.0-cp38-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/pablolube/IROS26-LaRovernetta/.venv/lib/python3.10/site-packages (from huggingface_hub) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /home/pablolube/IROS26-LaRovernetta/.venv/lib/python3.10/site-packages (from huggingface_hub) (26.3)
# Requirement already satisfied: pyyaml>=5.1 in /home/pablolube/IROS26-LaRovernetta/.venv/lib/python3.10/site-packages (from huggingface_hub) (6.0.3)
# Requirement already satisfied: tomli>=1.1.0 in /home/pablolube/IROS26-LaRovernetta/.venv/lib/python3.10/site-packages (from huggingface_hub) (2.4.1)
# Requirement already satisfied: tqdm>=4.42.1 in /home/pablolube/IROS26-LaRovernetta/.venv/lib/python3.10/site-packages (from huggingface_hub) (4.70.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /home/pablolube/IROS26-LaRovernetta/.venv/lib/python3.10/site-packages (from huggingface_hub) (4.16.0)
# Requirement already satisfied: anyio in /home/pablolube/IROS26-LaRovernetta/.venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (4.15.1)
# Requirement already satisfied: certifi in /home/pablolube/IROS26-LaRovernetta/.venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /home/pablolube/IROS26-LaRovernetta/.venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.0.9)
# Requirement already satisfied: idna in /home/pablolube/IROS26-LaRovernetta/.venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (3.20)
# Requirement already satisfied: h11>=0.16 in /home/pablolube/IROS26-LaRovernetta/.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub) (0.16.0)
# Requirement already satisfied: numpy>=1.22.4 in /home/pablolube/IROS26-LaRovernetta/.venv/lib/python3.10/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/pablolube/IROS26-LaRovernetta/.venv/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/pablolube/IROS26-LaRovernetta/.venv/lib/python3.10/site-packages (from pandas) (2026.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /home/pablolube/IROS26-LaRovernetta/.venv/lib/python3.10/site-packages (from pandas) (2026.4)
# Requirement already satisfied: six>=1.5 in /home/pablolube/IROS26-LaRovernetta/.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/pablolube/IROS26-LaRovernetta/.venv/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->huggingface_hub) (1.3.1)
# Downloading huggingface_hub-1.32.0-py3-none-any.whl (842 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 842.9/842.9 kB 7.7 MB/s  0:00:00
# Downloading hf_xet-1.6.0-cp38-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 11.3 MB/s  0:00:00 eta 0:00:01
# Downloading pyarrow-25.0.1-cp310-cp310-manylinux_2_28_x86_64.whl (50.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 MB 11.7 MB/s  0:00:04m0:00:0100:01
# Installing collected packages: pyarrow, hf-xet, huggingface_hub
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [huggingface_hub] [huggingface_hub]
# Successfully installed hf-xet-1.6.0 huggingface_hub-1.32.0 pyarrow-25.0.1

# %%
from huggingface_hub import hf_hub_download
import pandas as pd

path = hf_hub_download(
    repo_id="BitRobot/FrodoBots-Mini-4K",
    filename="metadata.parquet",
    repo_type="dataset",
)
meta = pd.read_parquet(path)
print(meta.shape)
print(meta.columns.tolist())
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# (14141, 27)
# ['folder', 'ride_id', 'device_ref_id', 'start_utc', 'source', 'db_dur_sec', 'n_epochs', 'hardware_version', 'drive_mode', 'country', 'city', 'front_footage_sec', 'rear_footage_sec', 'has_rear_camera', 'has_control', 'has_gps', 'has_imu', 'has_front_ts', 'has_rear_ts', 'has_mic_ts', 'has_speaker_ts', 'n_video_ts', 'has_video', 'complete', 'audio_only', 'shard', 'shard_member_bytes']

# %%
meta["country"].value_counts()
# Out:
# country
# China             4314
# Philippines       4180
# United States     1484
# Vietnam           1483
# Unknown            501
# India              404
# Kenya              288
# Mexico             189
# Taiwan             185
# New Zealand        163
# Panama             113
# Canada             111
# Costa Rica          88
# Malaysia            84
# United Kingdom      83
# Germany             72
# Botswana            68
# Australia           64
# Brazil              62
# Mauritius           46
# Indonesia           38
# Sweden              27
# Turkey              25
# Nigeria             18
# Chile               16
# Argentina           15
# Estonia              8
# Netherlands          6
# Singapore            4
# Japan                2
# Name: count, dtype: int64
